# %%
import pandas as pd

# %%
coop = pd.read_csv("Part2 Data/Canada/Co-operation on innovation activities, by type and location of co-operation partners by industry and enterprise size.csv")

# %%
def find_coop(dataset, col):
    """
    Filters the dataset for specific NAICS sectors and specific STATUS values ('B' or 'E') 
    and selects relevant columns.

    Parameters:
    - dataset: pandas DataFrame containing the data.
    - col: The name of the column to include in the output.

    Returns:
    - A filtered DataFrame with relevant columns.
    """
    # Filter for specific NAICS sectors
    filtered_sector = dataset[
        dataset['North American Industry Classification System (NAICS)'].isin([
            'Information and cultural industries [51]',
            'Professional, scientific and technical services [54]',
            'Manufacturing [31-33]'
        ])
    ]
    
    # Filter for STATUS values ('B' or 'E')
    filtered_sector = filtered_sector[filtered_sector["STATUS"].isin(["B", "E"])]

    # Select relevant columns
    selected_columns = filtered_sector[['North American Industry Classification System (NAICS)', 
                                        col, 
                                        "VALUE",
                                        "STATUS"]]
    return selected_columns

# %%
find_coop(coop,"Co-operation on innovation activities")
# Out:
#     North American Industry Classification System (NAICS)  \
# 61                               Manufacturing [31-33]
# 62                               Manufacturing [31-33]
# 63                               Manufacturing [31-33]
# 145           Information and cultural industries [51]
# 146           Information and cultural industries [51]
# 147           Information and cultural industries [51]
# 149           Information and cultural industries [51]
# 150           Information and cultural industries [51]
# 151           Information and cultural industries [51]
# 154           Information and cultural industries [51]
# 155           Information and cultural industries [51]
# 181  Professional, scientific and technical service...
# 182  Professional, scientific and technical service...
# 183  Professional, scientific and technical service...
# 184  Professional, scientific and technical service...
# 185  Professional, scientific and technical service...
# 186  Professional, scientific and technical service...
# 187  Professional, scientific and technical service...
# 188  Professional, scientific and technical service...
# 189  Professional, scientific and technical service...
# 190  Professional, scientific and technical service...
# 191  Professional, scientific and technical service...
#
#                  Co-operation on innovation activities  VALUE STATUS
# 61   Parent, affiliated or subsidiary businesses, t...   34.2      B
# 62   Suppliers of equipment, materials, components ...   55.6      B
# 63   Clients or customers from the private sector, ...   40.0      B
# 145  Parent, affiliated or subsidiary businesses, t...   43.7      B
# 146  Suppliers of equipment, materials, components ...   45.9      B
# 147  Clients or customers from the private sector, ...   45.9      B
# 149  Competitors or other businesses in the sector,...   17.2      B
# 150  Consultants and commercial laboratories, type ...   16.6      B
# 151  Universities, colleges or other higher educati...   11.4      B
# 154  Households or individuals, type of co-operatio...    4.6      B
# 155  Other co-operation partners, type of co-operat...   11.1      B
# 181  Parent, affiliated or subsidiary businesses, t...   35.9      B
# 182  Suppliers of equipment, materials, components ...   35.0      B
# 183  Clients or customers from the private sector, ...   45.2      B
# 184  Clients or customers from the public sector, t...   18.3      B
# 185  Competitors or other businesses in the sector,...   16.2      B
# 186  Consultants and commercial laboratories, type ...   18.4      B
# 187  Universities, colleges or other higher educati...   32.7      B
# 188  Government, public or private research institu...   20.8      B
# 189  Non-profit organizations, type of co-operation...   10.5      B
# 190  Households or individuals, type of co-operatio...    4.5      B
# 191  Other co-operation partners, type of co-operat...   13.9      B

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_innovation_activities_pie(data, naics_categories, value_column, activity_column, naics_column):
    """
    Creates pie charts for co-operation on innovation activities for specified NAICS categories.

    Parameters:
    - data: DataFrame containing the dataset.
    - naics_categories: List of NAICS categories to filter and plot.
    - value_column: The column name containing the values for the activities.
    - activity_column: The column name containing the activity names.
    - naics_column: The column name containing the NAICS categories.
    """
    # Filter rows where the NAICS column matches the specified categories
    filtered_data = data[data[naics_column].isin(naics_categories)]

    # Set consistent figure size
    figsize = (6, 6)

    # Function to create a pie chart for a specific NAICS category
    def plot_for_naics_category(category_data, title):
        plt.figure(figsize=figsize)  # Consistent figure size for all pie charts
        plt.pie(
            category_data[value_column],
            labels=category_data[activity_column],
            autopct='%1.1f%%',
            startangle=90,  # Start angle at 90 for consistency
            textprops={'fontsize': 10}  # Font size for better readability
        )
        plt.title(title, fontsize=12)
        plt.axis('equal')  # Ensure the pie chart is a perfect circle
        plt.tight_layout()
        plt.show()

    # Loop through each NAICS category and generate a plot
    for naics in naics_categories:
        category_data = filtered_data[filtered_data[naics_column] == naics]
        if not category_data.empty:
            plot_for_naics_category(
                category_data,
                f'Co-operation on Innovation Activities in {naics}'
            )

# Ensure `find_coop` is defined, or use the provided filtered dataset as input
coop = find_coop(coop, "Co-operation on innovation activities")

# Define the categories
naics_categories = [
    'Information and cultural industries [51]',
    'Professional, scientific and technical services [54]',
    'Manufacturing [31-33]'
]

# Call the plotting function
plot_innovation_activities_pie(
    data=coop,
    naics_categories=naics_categories,
    value_column='VALUE',
    activity_column='Co-operation on innovation activities',
    naics_column='North American Industry Classification System (NAICS)'
)

# %% [markdown]
# ## Co-operation on innovation activities

# %%
plot_innovation_activities_pie(
    data=coop,
    naics_categories=naics_categories,
    value_column='VALUE',
    activity_column='Co-operation on innovation activities',
    naics_column='North American Industry Classification System (NAICS)'
)
# Out:
# /var/folders/st/ygxnyth53pb99pxw1676p2qm0000gn/T/ipykernel_11657/1294617849.py:33: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ## "Most critical government program"

# %%
goverment_program = pd.read_csv("Part2 Data/Canada/Most critical government program for the business_s innovation activities, by industry and enterprise size.csv")
find_coop(goverment_program, "Most critical government program")
# Out:
#    North American Industry Classification System (NAICS)  \
# 60           Information and cultural industries [51]
# 61           Information and cultural industries [51]
# 75  Professional, scientific and technical service...
# 76  Professional, scientific and technical service...
# 77  Professional, scientific and technical service...
#
#                      Most critical government program  VALUE STATUS
# 60  Government tax incentive or tax credit program...   55.7      B
# 61  Government grants and contributions programs, ...   29.0      B
# 75  Government tax incentive or tax credit program...   51.7      B
# 76  Government grants and contributions programs, ...   25.8      B
# 77  Government training and hiring programs, most ...   17.9      B

# %%
goverment_program = find_coop(goverment_program, "Most critical government program")

plot_innovation_activities_pie(
    data=goverment_program,
    naics_categories=naics_categories,
    value_column='VALUE',
    activity_column="Most critical government program",
    naics_column='North American Industry Classification System (NAICS)'
)
# Out:
# /var/folders/st/ygxnyth53pb99pxw1676p2qm0000gn/T/ipykernel_11657/1294617849.py:33: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ## "Most critical type of co-operation partner"

# %%
critical_partner = pd.read_csv("Part2 Data/Canada/Most critical co-operation partner for the business_s innovation activities, by industry and enterprise size.csv")
find_coop(critical_partner, "Most critical type of co-operation partner")
# Out:
#     North American Industry Classification System (NAICS)  \
# 56                               Manufacturing [31-33]
# 57                               Manufacturing [31-33]
# 132           Information and cultural industries [51]
# 133           Information and cultural industries [51]
# 134           Information and cultural industries [51]
# 137           Information and cultural industries [51]
# 139           Information and cultural industries [51]
# 140           Information and cultural industries [51]
# 165  Professional, scientific and technical service...
# 166  Professional, scientific and technical service...
# 167  Professional, scientific and technical service...
# 169  Professional, scientific and technical service...
# 173  Professional, scientific and technical service...
# 174  Professional, scientific and technical service...
# 175  Professional, scientific and technical service...
#
#             Most critical type of co-operation partner  VALUE STATUS
# 56   Suppliers of equipment, materials, components ...   30.7      B
# 57   Clients or customers from the private sector, ...   22.5      B
# 132  Parent, affiliated or subsidiary businesses, m...   28.8      B
# 133  Suppliers of equipment, materials, components ...   18.0      B
# 134  Clients or customers from the private sector, ...   31.8      E
# 137  Consultants and commercial laboratories, most ...    7.1      B
# 139  Government, public or private research institu...    0.0      E
# 140            Non-profit organizations, most critical    0.0      E
# 165  Parent, affiliated or subsidiary businesses, m...   25.6      B
# 166  Suppliers of equipment, materials, components ...   17.5      B
# 167  Clients or customers from the private sector, ...   22.0      B
# 169  Competitors or other businesses in the sector,...    4.6      B
# 173            Non-profit organizations, most critical    5.2      B
# 174           Households or individuals, most critical    0.0      E
# 175                      Other partners, most critical   12.0      B

# %%
plot_innovation_activities_pie(
    data=critical_partner,
    naics_categories=naics_categories,
    value_column='VALUE',
    activity_column= "Most critical type of co-operation partner",
    naics_column='North American Industry Classification System (NAICS)'
)
# Out:
# /var/folders/st/ygxnyth53pb99pxw1676p2qm0000gn/T/ipykernel_11657/1294617849.py:33: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ## "Obstacles to innovation"

# %%
obstacles = pd.read_csv("Part2 Data/Canada/Obstacles to innovation and measures taken, by industry and enterprise size.csv")
find_coop(obstacles, "Obstacles to innovation")
# Out:
#     North American Industry Classification System (NAICS)  \
# 135           Information and cultural industries [51]
# 137           Information and cultural industries [51]
# 142           Information and cultural industries [51]
# 165  Professional, scientific and technical service...
# 168  Professional, scientific and technical service...
# 170  Professional, scientific and technical service...
# 173  Professional, scientific and technical service...
# 175  Professional, scientific and technical service...
#
#                                Obstacles to innovation  VALUE STATUS
# 135             Lack of skills, obstacle to innovation   30.8      B
# 137       Uncertainty and risk, obstacle to innovation   32.8      B
# 142                At least one obstacle to innovation   58.7      B
# 165                Market size, obstacle to innovation   17.8      B
# 168             Lack of skills, obstacle to innovation   27.4      B
# 170       Uncertainty and risk, obstacle to innovation   34.4      B
# 173  Impacts caused by COVID-19, obstacle to innova...   33.5      B
# 175                At least one obstacle to innovation   56.8      B

# %%
plot_innovation_activities_pie(
    data=obstacles,
    naics_categories=naics_categories,
    value_column='VALUE',
    activity_column= "Obstacles to innovation",
    naics_column='North American Industry Classification System (NAICS)'
)
# Out:
# /var/folders/st/ygxnyth53pb99pxw1676p2qm0000gn/T/ipykernel_11657/1294617849.py:33: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
